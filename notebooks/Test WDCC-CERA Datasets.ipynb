# %%
import json
import requests
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['axes.grid'] = True
import pandas as pd
import seaborn as sns 
import itertools

# %%
dkrz_identifier_prefix = 'http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?acronym='
dkrz_service = 'https://cera-www.dkrz.de/WDCC/ui/cerasearch/solr/select?wt=json&fl=entry_acronym_s&q=*%3A*&start=0&rows=1000&fq=entry_type_s%3A%22dataset%22'
max_dataset = 100
fuji_service = 'http://seprojects.marum.de:1071/fuji/api/v1/evaluate'
datasets = []
data_dir = 'results'

# %%
metrics = []
try:
    request = requests.get('http://seprojects.marum.de:1071/fuji/api/v1/metrics',headers={'Content-Type': 'application/json'}, auth=('marvel', 'wonderwoman'))
    mm = request.json()['metrics']
    for m in mm:
        metrics.append({k: m[k] for k in ('metric_identifier', 'metric_name', 'total_score')})
except requests.exceptions.RequestException as e:
    print(e)
except requests.exceptions.ConnectionError as e1:
    print(e1)

# %%
df_metrics = pd.DataFrame.from_dict(metrics)
df_metrics
# Out:
#    metric_identifier                                        metric_name  \
# 0         FsF-F1-01D  Data is assigned with a globally unique identi...
# 1         FsF-F1-02D     Data is assigned with a persistent identifier.
# 2         FsF-F2-01M  Metadata include descriptive core elements (cr...
# 3         FsF-F3-01M  Metadata includes the identifier of the data i...
# 4         FsF-F4-01M  Metadata is offered in such a way that it can ...
# 5         FsF-A1-01M  Metadata contains the access level and access ...
# 6         FsF-I1-01M  Metadata is represented using a formal knowled...
# 7         FsF-I1-02M            Metadata uses common semantic resources
# 8         FsF-I3-01M  Metadata includes links between the data and i...
# 9        FsF-R1-01MD  Metadata includes the descriptions of the cont...
# 10      FsF-R1.1-01M  Metadata includes license information under wh...
# 11      FsF-R1.2-01M  Metadata includes provenance information about...
# 12      FsF-R1.3-01M  Metadata follows a standard endorsed by a give...
# 13      FsF-R1.3-02D  Data available in file format backed by the re...
#
#     total_score
# 0             1
# 1             1
# 2             2
# 3             2
# 4             3
# 5             1
# 6             2
# 7             1
# 8             1
# 9             4
# 10            1
# 11            2
# 12            1
# 13            1

# %%
#http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?acronym=DKRZ_LTA_1075_ds00001
try:
    req = requests.get(dkrz_service)
    raw = req.json()
    hits = raw['response']['docs']
    datasets = [dkrz_identifier_prefix+li['entry_acronym_s'] for li in hits]
except requests.exceptions.RequestException as e:
    print(e)
except requests.exceptions.ConnectionError as e1:
    print(e1)

# %%
datasets[:2]
# Out:
# ['http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?acronym=DKRZ_LTA_1075_ds00001',
#  'http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?acronym=DKRZ_LTA_579_ds00003']

# %%
datasets = datasets[:max_dataset]

# %%
print('Total datasets :', len(datasets))
# Out:
# Total datasets : 100

# %%
datasets[:10]
# Out:
# ['http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?acronym=DKRZ_LTA_1075_ds00001',
#  'http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?acronym=DKRZ_LTA_579_ds00003',
#  'http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?acronym=DKRZ_LTA_579_ds00004',
#  'http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?acronym=DKRZ_LTA_834_ds00049',
#  'http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?acronym=DKRZ_LTA_834_ds00050',
#  'http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?acronym=DKRZ_LTA_834_ds00051',
#  'http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?acronym=DKRZ_LTA_738_ds00004',
#  'http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?acronym=DKRZ_LTA_203_ds00001',
#  'http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?acronym=DKRZ_LTA_738_ds00005',
#  'http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?acronym=DKRZ_LTA_834_ds00048']

# %%
# %%time
all_records = []
if len(datasets) == 100:
    for d in datasets:
        req = {'object_identifier':d, 'test_debug':True}
        r = requests.post(fuji_service, data=json.dumps(req), headers={'Content-Type': 'application/json'}, auth=('marvel', 'wonderwoman'))
        json_data = r.json()
        records = {}
        records['identifier'] = d
        records['result'] = json_data
        all_records.append(records)
# Out:
# Wall time: 4min 12s

# %%
with open(data_dir+'/'+'wdcc.json', 'w') as f:
    json.dump(all_records, f)

# %%
with open(data_dir+'/'+'wdcc.json') as json_file:
    data = json.load(json_file)

# %%
def get_assessment_result(id):
    jsn = None
    for data_dict in data:
        if data_dict['identifier'] == id:
            jsn = data_dict['result']
    return jsn

# %%
get_assessment_result('http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?acronym=DKRZ_LTA_834_ds00048')
# Out:
# [{'id': 1,
#   'metric_identifier': 'FsF-F1-01D',
#   'metric_name': 'Data is assigned with a globally unique identifier.',
#   'output': {'guid': 'http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?acronym=DKRZ_LTA_834_ds00048',
#    'guid_scheme': 'url'},
#   'score': {'earned': 1, 'total': 1},
#   'test_debug': ["INFO: Unique identifier schemes found ['url']",
#    'INFO: Finalized unique identifier scheme - url'],
#   'test_status': 'pass'},
#  {'id': 2,
#   'metric_identifier': 'FsF-F1-02D',
#   'metric_name': 'Data is assigned with a persistent identifier.',
#   'output': {'pid': None,
#    'pid_scheme': None,
#    'resolvable_status': True,
#    'resolved_url': 'https://cera-www.dkrz.de/WDCC/ui/cerasearch/entry?acronym=DKRZ_LTA_834_ds00048'},
#   'score': {'earned': 0, 'total': 1},
#   'test_debug': ['WARNING: Not a persistent identifier scheme - url',
#    'INFO: Retrieving page http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?acronym=DKRZ_LTA_834_ds00048',
#    'INFO: Content negotiation accept=text/html, application/xhtml+xml, status=200',
#    'INFO: Found HTML page!',
#    'INFO: Object identifier active (status code = 200)'],
#   'test_status': 'fail'},
#  {'id': 3,
#   'metric_identifier': 'FsF-F2-01M',
#   'metric_name': 'Metadata include descriptive core elements (creator, title, data identifier, publisher, publication date, summary and keywords) to support data findability.',
#   'output': {'core_metadata_found': {'creator': ['not yet available'],
#     'keywords': [],
#     'object_identifier': 'http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?acronym=DKRZ_LTA_834_ds00048',
#     'publication_date': '2020-01-29',
#     'publisher': 'World Data Center for Climate (WDCC) at DKRZ',
#     'summary': 'List of files and data related to the Noth Atlantik Paper of Fabian Senf, 2020',
#     'title': 'not filled'},
#    'core_metadata_source': ['Schema.org JSON-LD (Embedded)',
#     'Embedded DublinCore'],
#    'core_metadata_status': 'all metadata'},
#   'score': {'earned': 2, 'total': 2},
#   'test_debug': ["INFO: Formats of structured metadata embedded in HTML markup dict_keys(['json-ld', 'rdfa'])",
#    'INFO: Extract metadata from Schema.org JSON-LD (Embedded)',
#    'INFO: Extract DublinCore metadata from html page',
#    'INFO: Not a PID, therefore Datacite metadata (json) not requested.',
#    'INFO: Extract metadata from Linked Data (RDF)',
#    'INFO: Retrieving page https://cera-www.dkrz.de/WDCC/ui/cerasearch/entry?acronym=DKRZ_LTA_834_ds00048',
#    'INFO: Content negotiation accept=text/turtle, application/turtle, application/x-turtle;q=0.8, application/rdf+xml, text/n3;q=0.9, text/rdf+n3;q=0.9, status=200',
#    'INFO: Found HTML page!',
#    'INFO: Expected RDF Graph but received - text/html',
#    'INFO: Linked Data metadata UNAVAILABLE',
#    'INFO: Type of object described by the metadata - Dataset',
#    "INFO: Required core metadata ['creator', 'title', 'publisher', 'publication_date', 'summary', 'keywords', 'object_identifier']"],
#   'test_status': 'pass'},
#  {'id': 4,
#   'metric_identifier': 'FsF-F3-01M',
#   'metric_name': 'Metadata includes the identifier of the data it describes.',
#   'output': {'content': [],
#    'object_identifier_included': 'http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?acronym=DKRZ_LTA_834_ds00048'},
#   'score': {'earned': 0, 'total': 2},
#   'test_debug': ['INFO: Object identifier specified http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?acronym=DKRZ_LTA_834_ds00048',
#    'WARNING: Data (content) identifier is missing.'],
#   'test_status': 'fail'},
#  {'id': 5,
#   'metric_identifier': 'FsF-F4-01M',
#   'metric_name': 'Metadata is offered in such a way that it can be retrieved programmatically.',
#   'output': {'search_mechanisms': [{'mechanism': 'structured data',
#      'mechanism_info': ['Embedded DublinCore',
#       'Schema.org JSON-LD (Embedded)']}]},
#   'score': {'earned': 2, 'total': 3},
#   'test_debug': ["INFO: Supported metadata retrieval/extraction - 'Embedded DublinCore', 'Embedded OpenGraph', 'Schema.org JSON-LD (Embedded)', 'Schema.org JSON-LD (Negotiated)', 'Datacite Search', 'Signposting Typed Links', 'RDF-based Typed Links', 'Linked Data (RDF)', 'B2FIND Metadata Aggregator'",
#    "WARNING: Metadata NOT found through - ['Schema.org JSON-LD (Negotiated)', 'Datacite Search']"],
#   'test_status': 'pass'},
#  {'id': 6,
#   'metric_identifier': 'FsF-A1-01M',
#   'metric_name': 'Metadata contains the access level and access conditions of the data.',
#   'output': {'access_details': {}, 'access_level': None},
#   'score': {'earned': 0, 'total': 1},
#   'test_debug': ['WARNING: NO access information is available in metadata',
#    'WARNING: Unable to determine the access level'],
#   'test_status': 'fail'},
#  {'id': 7,
#   'metric_identifier': 'FsF-I1-01M',
#   'metric_name': 'Metadata is represented using a formal knowledge representation language.',
#   'output': [{'is_metadata_found': True,
#     'serialization_format': 'JSON-LD',
#     'source': 'structured_data'}],
#   'score': {'earned': 1, 'total': 2},
#   'test_debug': ['INFO: Check of structured data (RDF serialization) embedded in the data page',
#    'INFO: RDF Serialization found in the data page - JSON-LD',
#    'INFO: Check if RDF-based typed link included',
#    'INFO: NO RDF-based typed link found',
#    'INFO: Check if RDF metadata available through content negotiation',
#    'INFO: NO RDF metadata available through content negotiation',
#    'WARNING: NO SPARQL endpoint found through re3data based on the object URI provided'],
#   'test_status': 'pass'},
#  {'id': 8,
#   'metric_identifier': 'FsF-I1-02M',
#   'metric_name': 'Metadata uses common semantic resources',
#   'output': [{'is_namespace_active': True, 'namespace': 'http://schema.org/'}],
#   'score': {'earned': 0, 'total': 1},
#   'test_debug': ['INFO: Number of vocabulary namespaces extracted from all RDF-based metadata - 2',
#    "INFO: Default vocabulary namespace(s) excluded - ['http://purl.org/dc/elements/1.1/']",
#    "INFO: Check the remaining namespace(s) exists in LOD - ['http://schema.org/']",
#    "INFO: Namespace matches found - ['http://schema.org/']"],
#   'test_status': 'pass'},
#  {'id': 9,
#   'metric_identifier': 'FsF-I3-01M',
#   'metric_name': 'Metadata includes links between the data and its related entities.',
#   'output': [{'related_resource': 'http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?acronym=DKRZ_LTA_834_ds00048',
#     'relation_type': 'isBasedOn'}],
#   'score': {'earned': 1, 'total': 1},
#   'test_debug': ['INFO: No related resource(s) found in Schema.org metadata',
#    'INFO: 1 related resource(s) extracted from Embedded DublinCore'],
#   'test_status': 'pass'},
#  {'id': 9,
#   'metric_identifier': 'FsF-R1-01MD',
#   'metric_name': 'Metadata includes the descriptions of the content of the data.',
#   'output': {'data_content_descriptor': [], 'object_type': 'Dataset'},
#   'score': {'earned': 1, 'total': 4},
#   'test_debug': ['INFO: Resource type specified - Dataset',
#    'WARNING: NO object content available to perform file descriptors (type and size) tests',
#    "WARNING: NO measured variables found in metadata, skip 'measured_variable' test."],
#   'test_status': 'fail'},
#  {'id': 10,
#   'metric_identifier': 'FsF-R1.1-01M',
#   'metric_name': 'Metadata includes license information under which the data can be reused.',
#   'output': [],
#   'score': {'earned': 0, 'total': 1},
#   'test_debug': ['WARNING: NO license information is included in metadata'],
#   'test_status': 'fail'},
#  {'id': 10,
#   'metric_identifier': 'FsF-R1.2-01M',
#   'metric_name': 'Metadata includes provenance information about data collection or generation.',
#   'output': {'creation_provenance_included': {'is_available': True,
#     'provenance_metadata': [{'title': 'not filled'},
#      {'publication_date': '2020-01-29'},
#      {'creator': 'not yet available'}]},
#    'modification_provenance_included': {'is_available': False,
#     'provenance_metadata': []},
#    'provenance_relations_included': {'is_available': True,
#     'provenance_metadata': [{'isBasedOn': 'http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?acronym=DKRZ_LTA_834_ds00048'}]},
#    'structured_provenance_available': {'is_available': False,
#     'provenance_metadata': []}},
#   'score': {'earned': 1.0, 'total': 2},
#   'test_debug': ['INFO: Found basic creation-related provenance information',
#    'WARNING: Data modification/versioning information NOT found.',
#    'INFO: Found basic process-related provenance information'],
#   'test_status': 'pass'},
#  {'id': 11,
#   'metric_identifier': 'FsF-R1.3-01M',
#   'metric_name': 'Metadata follows a standard endorsed by a given research community.',
#   'output': [],
#   'score': {'earned': 0, 'total': 1},
#   'test_debug': ['INFO: Retrieving API and Standards from R3DATA',
#    'INFO: R3DATA/Datacite client id - None',
#    'WARNING: Unable to determine community standard'],
#   'test_status': 'fail'},
#  {'id': 12,
#   'metric_identifier': 'FsF-R1.3-02D',
#   'metric_name': 'Data available in file format backed by the research community.',
#   'output': [],
#   'score': {'earned': 0, 'total': 1},
#   'test_debug': ['INFO: Could not perform file format checks, no object content identifiers available'],
#   'test_status': 'fail'}]

# %%
final = []
for data_dict in data:
    results = {}
    results['identifier'] = data_dict['identifier']
    dd = data_dict['result'] # list of dict
    for d in dd:
        metric_identifier = d['metric_identifier']
        sub_principle = metric_identifier.split('-')[1]
        principle = sub_principle[0]+'_earned'
        principle_total = sub_principle[0]+'_total'
        if not sub_principle in results:
            results[sub_principle] = d['score']['earned']
        else:
            results[sub_principle] += d['score']['earned']
        if not principle in results:
            results[principle] = d['score']['earned']
        else:
            results[principle] += d['score']['earned']
        if not principle_total in results:
            results[principle_total] = d['score']['total']
        else:
            results[principle_total] += d['score']['total']
    final.append(results)

# %%
df_results = pd.DataFrame.from_dict(final)

# %%
cols = ['identifier','F1','F2','F3','F4','A1','A1','I1','I3','R1','R1.1','R1.2','R1.3','F_earned','F_total','A_earned','A_total','I_earned','I_total','R_earned','R_total']
df_results = df_results[cols]

# %%
df_results.head()
# Out:
#                                           identifier  F1  F2  F3  F4  A1  A1  \
# 0  http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?ac...   1   2   0   2   0   0
# 1  http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?ac...   1   0   0   2   0   0
# 2  http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?ac...   1   0   0   2   0   0
# 3  http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?ac...   1   2   0   2   0   0
# 4  http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?ac...   1   2   0   2   0   0
#
#    I1  I3  R1  ...  R1.2  R1.3  F_earned  F_total  A_earned  A_total  \
# 0   1   1   1  ...   1.0     0         5        9         0        1
# 1   1   0   1  ...   0.0     0         3        9         0        1
# 2   1   0   1  ...   0.0     0         3        9         0        1
# 3   1   1   1  ...   1.0     0         5        9         0        1
# 4   1   1   1  ...   1.0     0         5        9         0        1
#
#    I_earned  I_total  R_earned  R_total
# 0         2        4       2.0        9
# 1         1        4       1.0        9
# 2         1        4       1.0        9
# 3         2        4       2.0        9
# 4         2        4       2.0        9
#
# [5 rows x 21 columns]

# %%
df_results ['F_Principle'] = (df_results ['F_earned'] / df_results ['F_total'] * 100).round()
df_results ['A_Principle'] = (df_results ['A_earned'] / df_results ['A_total'] * 100).round()
df_results ['I_Principle'] = (df_results ['I_earned'] / df_results ['I_total'] * 100).round()
df_results ['R_Principle' ]= (df_results ['I_total'] / df_results ['R_total'] * 100).round()

# %%
df_results.head()
# Out:
#                                           identifier  F1  F2  F3  F4  A1  A1  \
# 0  http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?ac...   1   2   0   2   0   0
# 1  http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?ac...   1   0   0   2   0   0
# 2  http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?ac...   1   0   0   2   0   0
# 3  http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?ac...   1   2   0   2   0   0
# 4  http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?ac...   1   2   0   2   0   0
#
#    I1  I3  R1  ...  A_earned  A_total  I_earned  I_total  R_earned  R_total  \
# 0   1   1   1  ...         0        1         2        4       2.0        9
# 1   1   0   1  ...         0        1         1        4       1.0        9
# 2   1   0   1  ...         0        1         1        4       1.0        9
# 3   1   1   1  ...         0        1         2        4       2.0        9
# 4   1   1   1  ...         0        1         2        4       2.0        9
#
#    F_Principle  A_Principle  I_Principle  R_Principle
# 0         56.0          0.0         50.0         44.0
# 1         33.0          0.0         25.0         44.0
# 2         33.0          0.0         25.0         44.0
# 3         56.0          0.0         50.0         44.0
# 4         56.0          0.0         50.0         44.0
#
# [5 rows x 25 columns]

# %%
df_hist = df_results[['identifier','F_Principle','A_Principle','I_Principle','R_Principle']]
df_hist
# Out:
#                                            identifier  F_Principle  \
# 0   http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?ac...         56.0
# 1   http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?ac...         33.0
# 2   http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?ac...         33.0
# 3   http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?ac...         56.0
# 4   http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?ac...         56.0
# ..                                                ...          ...
# 95  http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?ac...         33.0
# 96  http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?ac...         33.0
# 97  http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?ac...         33.0
# 98  http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?ac...         33.0
# 99  http://cera-www.dkrz.de/WDCC/ui/Compact.jsp?ac...         33.0
#
#     A_Principle  I_Principle  R_Principle
# 0           0.0         50.0         44.0
# 1           0.0         25.0         44.0
# 2           0.0         25.0         44.0
# 3           0.0         50.0         44.0
# 4           0.0         50.0         44.0
# ..          ...          ...          ...
# 95          0.0         25.0         44.0
# 96          0.0         25.0         44.0
# 97          0.0         25.0         44.0
# 98          0.0         25.0         44.0
# 99          0.0         25.0         44.0
#
# [100 rows x 5 columns]

# %%
df_hist[df_hist.A_Principle >50]
# Out:
# Empty DataFrame
# Columns: [identifier, F_Principle, A_Principle, I_Principle, R_Principle]
# Index: []

# %%
df_hist.plot.hist(sharex=True,sharey=True,alpha=0.65,figsize = (8,6), title="FAIR Scores of WDCC CERA Datasets (n=100)")
plt.xlabel('FAIR Score')
# Out:
# Text(0.5, 0, 'FAIR Score')

# %%
def histograms_plot(dataframe, features, rows, cols):
    fig=plt.figure(figsize=(10,10))
    # set palette 
    palette = itertools.cycle(sns.color_palette())
    for i, feature in enumerate(features):
        c = next(palette)
        ax=fig.add_subplot(rows,cols,i+1)
        dataframe[feature].plot.hist(bins=10, ax=ax, color=c)
        ax.set_title("FAIR Score - "+feature+ ' (n=' + str(len(df_hist))+')')
        ax.set(xlabel="Score", ylabel="Frequency")
    fig.tight_layout()  
    plt.show()

# %%
histograms_plot(df_hist,df_hist.columns[1:],2,2)
